# %%
from tensorflow.keras.datasets import mnist

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load and data preprocessing
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print('x_train shape: ', str(x_train.shape))
print('y_train shape: ', str(y_train.shape))

# pad images with zeroes
# x_train_padded = np.array([
#     np.pad(img, pad_width=1, mode='constant', constant_values=0)
#     for img in x_train
# ])
# Out:
# x_train shape:  (60000, 28, 28)
# y_train shape:  (60000,)

# %%
# declare kernels
vertical_kernel = np.array([
    [-1, 0, 1],
    [-1, 0, 1],
    [-1, 0, 1]
], dtype=np.float32)

horizontal_kernel = np.array([
    [-1, -1, -1],
    [ 0,  0,  0],
    [ 1,  1,  1]
], dtype=np.float32)

sharpen_kernel = np.array([
    [ 0, -1,  0],
    [-1,  5, -1],
    [ 0, -1,  0]
], dtype=np.float32)

print("vertical kernel: \n", vertical_kernel)
# Out:
# vertical kernel:
#  [[-1.  0.  1.]
#  [-1.  0.  1.]
#  [-1.  0.  1.]]

# %%
# plotting one sample
image = x_train_padded[1]

fig = plt.figure
plt.imshow(image, cmap='gray_r')
plt.show()

# %%
# plotting multiple samples
num = 25
images = x_train_padded[:num]
labels = y_train[:num]

num_row = 5
num_col = 5

fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col, 1.5*num_row))
for i in range(num):
    ax = axes[i//num_col, i%num_col]
    ax.imshow(images[i], cmap='gray_r')
    ax.set_title('Label: {}'.format(labels[i]))
    ax.set_xticks([])
    ax.set_yticks([])
plt.tight_layout()
plt.show()
